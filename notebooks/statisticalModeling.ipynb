# %% [markdown]
# > # Statistical Modeling

# %%
import pandas as pd
import sys
sys.path.append('/content/statisticalModeling.py')

# %%
data = pd.read_csv('/content/MachineLearningRating.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  UnderwrittenCoverID  PolicyID TransactionMonth  \
# 0           0               145249     12827       2015-03-01
# 1           1               145249     12827       2015-05-01
# 2           2               145249     12827       2015-07-01
# 3           3               145255     12827       2015-05-01
# 4           4               145255     12827       2015-07-01
#
#    IsVATRegistered Citizenship          LegalType Title Language  \
# 0             True              Close Corporation    Mr  English
# 1             True              Close Corporation    Mr  English
# 2             True              Close Corporation    Mr  English
# 3             True              Close Corporation    Mr  English
# 4             True              Close Corporation    Mr  English
#
#                   Bank  ...                    ExcessSelected CoverCategory  \
# 0  First National Bank  ...             Mobility - Windscreen    Windscreen
# ...

# %% [markdown]
# > ## Data Preparation and Feature Engineering

# %%
import statisticalModeling

# %%
X_train, X_test, y_train, y_test, data = statisticalModeling.prepare_data(data, 'TotalClaims')

# %%
data.head(0)
# Out:
# Empty DataFrame
# ...

# %%
X_train.head(2)
# Out:
#        UnderwrittenCoverID  PolicyID  IsVATRegistered  PostalCode      mmcode  \
# 70253               112144      6901            False        7580  60058400.0
# 9626                166591     13388            False         200  60058407.0
#
#        RegistrationYear  Cylinders  cubiccapacity  kilowatts  NumberOfDoors  \
# 70253            2011.0        4.0         2494.0       75.0            4.0
# 9626             2012.0        4.0         2494.0       75.0            4.0
#
#        ...  CoverGroup_Income Protector  \
# 70253  ...                        False
# 9626   ...                        False
#
#        CoverGroup_Standalone passenger liability  CoverGroup_Third Party Only  \
# 70253                                      False                        False
# 9626                                       False                        False
#
#        CoverGroup_Trailer  Section_Motor Comprehensive  \
# 70253               False                         True
# ...

# %%
X_test.head(2)
# Out:
#        UnderwrittenCoverID  PolicyID  IsVATRegistered  PostalCode      mmcode  \
# 56455                14991       691            False         122  60058418.0
# 9430                132673     10459            False         192  11511100.0
#
#        RegistrationYear  Cylinders  cubiccapacity  kilowatts  NumberOfDoors  \
# 56455            2011.0        4.0         2694.0      111.0            4.0
# 9430             2011.0        4.0         2398.0      102.0            4.0
#
#        ...  CoverGroup_Income Protector  \
# 56455  ...                        False
# 9430   ...                         True
#
#        CoverGroup_Standalone passenger liability  CoverGroup_Third Party Only  \
# 56455                                      False                        False
# 9430                                       False                        False
#
#        CoverGroup_Trailer  Section_Motor Comprehensive  \
# 56455               False                         True
# ...

# %%
y_train.head(2)
# Out:
# 70253    0.0
# 9626     0.0
# Name: TotalClaims, dtype: float64

# %%
y_test.head(2)
# Out:
# 56455    0.0
# 9430     0.0
# Name: TotalClaims, dtype: float64

# %% [markdown]
# > ### added AverageClaimPerPolicy, HighRiskFlag,PremiumToClaimsRatio, AverageClaimPerPolicy column to make the raw data smarter and more informative

# %% [markdown]
# >> ## Build model

# %%
models = statisticalModeling.build_models()

# %%
models
# Out:
# {'Linear Regression': LinearRegression(),
#  'Random Forest': RandomForestRegressor(random_state=42),
#  'XGBoost': XGBRegressor(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)}

# %% [markdown]
# >> ### Model Evaluation

# %%
results = statisticalModeling.train_and_evaluate_models(models, X_train, X_test, y_train, y_test)
# Out:
# Linear Regression - MAE: 0.2131, MSE: 0.1327, R2: 1.0000
# Random Forest - MAE: 4.2830, MSE: 25535.8377, R2: 0.9968
# XGBoost - MAE: 5.3426, MSE: 49685.6287, R2: 0.9937

# %% [markdown]
# >> ### Analyze feature importance

# %%
statisticalModeling.analyze_feature_importance_all(models, X_train)
# Out:
# Feature Importance for Linear Regression:
#                                                Feature   Importance
# 16                               AverageClaimPerPolicy  1127.991224
# 403  ExcessSelected_Mobility - Taxi with value more...     1.887470
# 97                           SubCrestaZone_North Coast     0.824741
# 104                            SubCrestaZone_Rand West     0.798248
# 420                          CoverCategory_Own Damage      0.616342
# ..                                                 ...          ...
# 105                          SubCrestaZone_South Coast    -0.331817
# 248                    Model_QUANTUM 2.7 SESFIKILE 15s    -0.336622
# 96                               SubCrestaZone_Natal 3    -0.520086
# 76                              SubCrestaZone_Bushveld    -0.557000
# 402  ExcessSelected_Mobility - Taxi with value more...    -0.941883
#
# [472 rows x 2 columns]
# Feature Importance for Random Forest:
# Feature Importance for XGBoost:
